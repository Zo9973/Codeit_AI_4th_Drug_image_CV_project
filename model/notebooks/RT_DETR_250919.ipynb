# %%
# 한글 폰트 설정
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

print("한글 폰트 설치 완료!")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 0s (47.9 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 126435 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded
# 한글 폰트 설치 완료!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 1. 기존 리포지토리 폴더로 이동
import os
os.chdir('/content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project')

# %%
# 2. 경로 확인
# !pwd
# Out:
# /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project

# %% [markdown]
# # RT-DETR 전처리 코드

# %% [markdown]
# ## 라이브러리 생성

# %%
# Colab에서 실행할 설치 명령어들
# !pip install ultralytics
# !pip install pandas pyyaml
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.203-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.2)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.23.0+cu126)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.25.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.17-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.203-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 40.3 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.17-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.203 ultralytics-thop-2.0.17
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (6.0.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import os
import json
import glob
import pandas as pd
from pathlib import Path
import cv2
import numpy as np
from ultralytics import RTDETR
import yaml
import shutil
from collections import defaultdict
from datetime import datetime
import copy
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# ## 전처리 클래스

# %%
class RTDETRDataProcessor:
    def __init__(self, data_path="./data"):
        self.data_path = data_path
        self.train_images_path = os.path.join(data_path, "train_images")
        self.train_ann_path = os.path.join(data_path, "train_annotations")
        self.test_images_path = os.path.join(data_path, "test_images")

        # YOLO 형식 출력 디렉토리
        self.output_dir = os.path.join(data_path, "yolo_format")
        os.makedirs(self.output_dir, exist_ok=True)

    def merge_coco_annotations(self):
        """COCO 형식 JSON 파일들을 하나로 병합 + 모든 dl_idx 매핑 저장 (수정된 버전)"""
        pattern = os.path.join(self.train_ann_path, "**", "*.json")
        json_files = glob.glob(pattern, recursive=True)

        merged_data = {
            "images": [],
            "annotations": [],
            "categories": []
        }

        # ID 재할당을 위한 매핑
        image_id_map = {}
        category_name_to_id = {}
        new_image_id = 0
        new_ann_id = 0
        new_cat_id = 0

        # 🔥 핵심: 모든 매핑을 저장하는 구조
        dl_idx_to_name_mapping = {}    # 모든 dl_idx → 약품명
        category_mapping = {}          # YOLO 클래스 ID → dl_idx
        processed_dl_idx = set()       # 중복 방지

        print(f"총 {len(json_files)}개의 JSON 파일 처리 중...")

        for json_file in json_files:
            try:
                with open(json_file, 'r', encoding='utf-8') as f:
                    data = json.load(f)

                # 파일 형식 확인
                categories = data.get('categories', [])
                is_broken_format = (len(categories) == 1 and
                                categories[0].get('name') == 'Drug' and
                                categories[0].get('id') == 1)

                if is_broken_format:
                    print(f"  새로운 형식: {os.path.basename(json_file)}")

                    # 새로운 형식: 이미지에서 dl_idx와 dl_name 추출
                    for img in data.get('images', []):
                        actual_dl_idx = img.get('dl_idx')
                        actual_dl_name = img.get('dl_name')

                        if actual_dl_idx and actual_dl_name:
                            if isinstance(actual_dl_idx, str):
                                actual_dl_idx = int(actual_dl_idx)

                            if actual_dl_idx not in processed_dl_idx:
                                processed_dl_idx.add(actual_dl_idx)

                                # 🔥 수정: 모든 매핑 저장
                                dl_idx_to_name_mapping[actual_dl_idx] = actual_dl_name

                                if actual_dl_name not in category_name_to_id:
                                    category_name_to_id[actual_dl_name] = new_cat_id
                                    category_mapping[str(new_cat_id)] = actual_dl_idx

                                    merged_data['categories'].append({
                                        'id': new_cat_id,
                                        'name': actual_dl_name,
                                        'supercategory': 'pill',
                                        'original_dl_idx': actual_dl_idx
                                    })

                                    print(f"    + {actual_dl_name} (dl_idx: {actual_dl_idx})")
                                    new_cat_id += 1

                else:
                    print(f"  기존 형식: {os.path.basename(json_file)}")

                    # 🔥 수정: 기존 형식도 매핑 저장
                    for cat in categories:
                        cat_name = cat['name']
                        original_dl_idx = cat['id']

                        if original_dl_idx not in processed_dl_idx:
                            processed_dl_idx.add(original_dl_idx)

                            # 🔥 핵심: 기존 데이터도 매핑 저장
                            dl_idx_to_name_mapping[original_dl_idx] = cat_name

                            if cat_name not in category_name_to_id:
                                category_name_to_id[cat_name] = new_cat_id
                                category_mapping[str(new_cat_id)] = original_dl_idx

                                merged_data['categories'].append({
                                    'id': new_cat_id,
                                    'name': cat_name,
                                    'supercategory': 'pill',
                                    'original_dl_idx': original_dl_idx
                                })

                                print(f"    + {cat_name} (dl_idx: {original_dl_idx})")
                                new_cat_id += 1

                # 이미지 처리 (기존과 동일)
                for img in data.get('images', []):
                    old_img_id = img['id']
                    image_id_map[old_img_id] = new_image_id
                    img['id'] = new_image_id
                    merged_data['images'].append(img)
                    new_image_id += 1

                # 어노테이션 처리 (수정됨)
                for ann in data.get('annotations', []):
                    ann['id'] = new_ann_id
                    ann['image_id'] = image_id_map[ann['image_id']]

                    if is_broken_format:
                        # 새로운 형식: 이미지에서 dl_idx 찾기
                        original_img_id = None
                        for orig_id, mapped_id in image_id_map.items():
                            if mapped_id == ann['image_id']:
                                original_img_id = orig_id
                                break

                        target_img = next((img for img in data['images'] if img['id'] == original_img_id), None)
                        if target_img and target_img.get('dl_idx'):
                            actual_dl_idx = int(target_img['dl_idx']) if isinstance(target_img['dl_idx'], str) else target_img['dl_idx']
                            actual_dl_name = target_img.get('dl_name')

                            if actual_dl_name in category_name_to_id:
                                ann['category_id'] = category_name_to_id[actual_dl_name]
                                merged_data['annotations'].append(ann)
                                new_ann_id += 1
                    else:
                        # 기존 형식
                        old_cat_id = ann['category_id']
                        target_cat = next((cat for cat in data['categories'] if cat['id'] == old_cat_id), None)

                        if target_cat and target_cat['name'] in category_name_to_id:
                            ann['category_id'] = category_name_to_id[target_cat['name']]
                            merged_data['annotations'].append(ann)
                            new_ann_id += 1

            except Exception as e:
                print(f"❌ 에러: {json_file} - {e}")
                continue

        # 🔥 수정: 모든 매핑 파일 저장
        print(f"\n📝 매핑 파일 저장 중...")

        # category_id_mapping.json (YOLO 클래스 → dl_idx)
        with open(os.path.join(self.output_dir, 'category_id_mapping.json'), 'w', encoding='utf-8') as f:
            json.dump(category_mapping, f, ensure_ascii=False, indent=2)

        # dl_idx_to_name.json (dl_idx → 약품명)
        with open(os.path.join(self.output_dir, 'dl_idx_to_name.json'), 'w', encoding='utf-8') as f:
            json.dump(dl_idx_to_name_mapping, f, ensure_ascii=False, indent=2)

        # dl_name_mapping.json (동일한 내용이지만 호환성을 위해)
        with open(os.path.join(self.output_dir, 'dl_name_mapping.json'), 'w', encoding='utf-8') as f:
            json.dump(dl_idx_to_name_mapping, f, ensure_ascii=False, indent=2)

        print(f"\n🎯 병합 결과:")
        print(f"  📊 총 카테고리: {len(merged_data['categories'])}개")
        print(f"  📊 총 이미지: {len(merged_data['images'])}개")
        print(f"  📊 총 어노테이션: {len(merged_data['annotations'])}개")
        print(f"  📊 매핑된 dl_idx: {len(dl_idx_to_name_mapping)}개")

        # 매핑 검증
        if len(dl_idx_to_name_mapping) != len(merged_data['categories']):
            print(f"  ⚠️  매핑 불일치 감지!")
            print(f"     카테고리: {len(merged_data['categories'])}개")
            print(f"     매핑: {len(dl_idx_to_name_mapping)}개")
        else:
            print(f"  ✅ 매핑 일치 확인")

        return merged_data

    def _find_actual_drug_name(self, dl_idx, data, dl_name_map):
        """dl_idx를 기반으로 실제 약품명 찾기"""

        # 방법 1: 해당 dl_idx를 가진 이미지들의 dl_name 확인
        for img in data.get('images', []):
            if img.get('dl_name') and 'annotations' in data:
                # 이 이미지의 어노테이션 중 해당 dl_idx를 가진 것 찾기
                for ann in data['annotations']:
                    if ann['image_id'] == img['id'] and ann['category_id'] == dl_idx:
                        return img.get('dl_name')

        # 방법 2: dl_name_map에서 직접 찾기
        if dl_name_map:
            for filename, drug_name in dl_name_map.items():
                # 파일명 패턴으로 매칭 시도
                if str(dl_idx) in filename:
                    return drug_name

        return None  # 찾지 못한 경우

    def validate_category_mapping(self):
        """카테고리 매핑 검증"""
        mapping_file = os.path.join(self.output_dir, 'category_id_mapping.json')
        dl_name_file = os.path.join(self.output_dir, 'dl_name_mapping.json')

        if os.path.exists(mapping_file) and os.path.exists(dl_name_file):
            with open(mapping_file, 'r') as f:
                category_mapping = json.load(f)
            with open(dl_name_file, 'r') as f:
                dl_name_mapping = json.load(f)

            print(f"\n🔍 매핑 검증:")
            print(f"  - 총 카테고리: {len(category_mapping)}개")
            print(f"  - dl_name 매핑: {len(dl_name_mapping)}개")

            # "Drug"가 남아있는지 확인
            generic_drugs = [name for name in dl_name_mapping.values() if "Drug_idx_" in name]
            if generic_drugs:
                print(f"  ⚠️  백업명 사용: {len(generic_drugs)}개")
                for drug in generic_drugs[:3]:  # 처음 3개만 출력
                    print(f"      {drug}")
            else:
                print(f"  ✅ 모든 약품명 매핑 완료")

        return True

    def coco_to_yolo_format(self, merged_data):
        """COCO 형식을 YOLO 형식으로 변환 + 매핑 파일 생성"""
        # 디렉토리 생성
        train_dir = os.path.join(self.output_dir, "train")
        val_dir = os.path.join(self.output_dir, "val")
        os.makedirs(os.path.join(train_dir, "images"), exist_ok=True)
        os.makedirs(os.path.join(train_dir, "labels"), exist_ok=True)
        os.makedirs(os.path.join(val_dir, "images"), exist_ok=True)
        os.makedirs(os.path.join(val_dir, "labels"), exist_ok=True)

        # 이미지 분할 (80:20)
        images = merged_data['images']
        np.random.seed(42)
        np.random.shuffle(images)
        split_idx = int(len(images) * 0.8)
        train_images = images[:split_idx]
        val_images = images[split_idx:]

        # 어노테이션을 이미지별로 그룹화
        ann_by_image = {}
        for ann in merged_data['annotations']:
            img_id = ann['image_id']
            if img_id not in ann_by_image:
                ann_by_image[img_id] = []
            ann_by_image[img_id].append(ann)

        # 훈련 데이터 처리
        self._process_split(train_images, ann_by_image, train_dir, "train")

        # 검증 데이터 처리
        self._process_split(val_images, ann_by_image, val_dir, "val")

        # 🔥 핵심: category_id 매핑 파일 생성 (제출용)
        category_mapping = {}
        original_dl_idx_mapping = {}

        for i, cat in enumerate(merged_data['categories']):
            # YOLO 훈련용 ID (0,1,2,3...)
            yolo_class_id = i

            # 실제 dl_idx 추출 (원본 JSON에서 보존된 값)
            original_dl_idx = cat.get('original_dl_idx', cat['id'])

            category_mapping[str(yolo_class_id)] = original_dl_idx
            original_dl_idx_mapping[original_dl_idx] = cat['name']

        # 매핑 파일들 저장
        with open(os.path.join(self.output_dir, 'category_id_mapping.json'), 'w', encoding='utf-8') as f:
            json.dump(category_mapping, f, ensure_ascii=False, indent=2)

        with open(os.path.join(self.output_dir, 'dl_idx_to_name.json'), 'w', encoding='utf-8') as f:
            json.dump(original_dl_idx_mapping, f, ensure_ascii=False, indent=2)

        print(f"\n🔥 매핑 파일 생성 완료:")
        print(f"  - category_id_mapping.json: YOLO 클래스 → dl_idx 매핑")
        print(f"  - dl_idx_to_name.json: dl_idx → 약품명 매핑")
        print(f"  - 총 {len(category_mapping)}개 클래스")

        # 매핑 예시 출력
        print(f"매핑 예시:")
        for yolo_id, dl_idx in list(category_mapping.items())[:5]:
            drug_name = original_dl_idx_mapping.get(dl_idx, "Unknown")
            print(f"  YOLO 클래스 {yolo_id} → dl_idx {dl_idx} ({drug_name})")

        # dataset.yaml 파일 생성
        yaml_data = {
            'path': self.output_dir,
            'train': 'train/images',
            'val': 'val/images',
            'nc': len(merged_data['categories']),
            'names': [cat['name'] for cat in merged_data['categories']]
        }

        with open(os.path.join(self.output_dir, 'dataset.yaml'), 'w', encoding='utf-8') as f:
            yaml.dump(yaml_data, f, allow_unicode=True)

        return merged_data

    def _process_split(self, images, ann_by_image, output_dir, split_name):
        """분할된 데이터 처리 (bbox 유효성 검사 포함)"""
        skipped_annotations = 0
        processed_annotations = 0

        for img_data in images:
            img_id = img_data['id']
            filename = img_data['file_name']

            # 이미지 복사
            src_path = os.path.join(self.train_images_path, filename)
            dst_path = os.path.join(output_dir, "images", filename)
            if os.path.exists(src_path):
                shutil.copy2(src_path, dst_path)

            # YOLO 라벨 생성
            label_filename = filename.replace('.png', '.txt').replace('.jpg', '.txt')
            label_path = os.path.join(output_dir, "labels", label_filename)

            with open(label_path, 'w') as f:
                if img_id in ann_by_image:
                    for ann in ann_by_image[img_id]:
                        # 🔥 bbox 유효성 검사 추가
                        bbox = ann.get('bbox', [])
                        if not bbox or len(bbox) != 4:
                            print(f"⚠️ 잘못된 bbox 건너뛰기: {bbox} (이미지: {filename})")
                            skipped_annotations += 1
                            continue

                        # COCO bbox를 YOLO 형식으로 변환
                        x, y, w, h = bbox

                        # 🔥 추가 유효성 검사 (음수 크기 방지)
                        if w <= 0 or h <= 0:
                            print(f"⚠️ 유효하지 않은 크기 건너뛰기: w={w}, h={h} (이미지: {filename})")
                            skipped_annotations += 1
                            continue

                        # 이미지 크기 정보
                        img_w, img_h = img_data['width'], img_data['height']

                        # 🔥 이미지 경계 체크
                        if x < 0 or y < 0 or (x + w) > img_w or (y + h) > img_h:
                            print(f"⚠️ 이미지 경계 초과 bbox 건너뛰기: ({x}, {y}, {w}, {h}) (이미지: {filename})")
                            skipped_annotations += 1
                            continue

                        # 정규화된 중심점 좌표와 크기
                        x_center = (x + w/2) / img_w
                        y_center = (y + h/2) / img_h
                        norm_w = w / img_w
                        norm_h = h / img_h

                        # 🔥 정규화된 값 범위 체크 (0~1 사이)
                        if not (0 <= x_center <= 1 and 0 <= y_center <= 1 and 0 <= norm_w <= 1 and 0 <= norm_h <= 1):
                            print(f"⚠️ 정규화 값 범위 초과: center=({x_center:.3f}, {y_center:.3f}), size=({norm_w:.3f}, {norm_h:.3f})")
                            skipped_annotations += 1
                            continue

                        class_id = ann['category_id']
                        f.write(f"{class_id} {x_center:.6f} {y_center:.6f} {norm_w:.6f} {norm_h:.6f}\n")
                        processed_annotations += 1

        # 🔥 처리 결과 요약
        print(f"\n📊 {split_name} 데이터 처리 완료:")
        print(f"  - 처리된 어노테이션: {processed_annotations}개")
        print(f"  - 건너뛴 어노테이션: {skipped_annotations}개")
        if skipped_annotations > 0:
            print(f"  - 성공률: {processed_annotations/(processed_annotations + skipped_annotations)*100:.1f}%")

    def process_data_with_name_mapping(self):
        """dl_name 매핑 포함 전체 데이터 처리"""
        print("=== dl_name 매핑 포함 데이터 전처리 시작 ===")

        print("1. COCO 어노테이션 병합 + dl_name 매핑 중...")
        merged_data = self.merge_coco_annotations()  # 개선된 버전

        print("2. 매핑 검증 중...")
        self.validate_category_mapping()

        print("3. YOLO 형식으로 변환 중...")
        self.coco_to_yolo_format(merged_data)

        print("✅ 데이터 전처리 완료 (dl_name 매핑 포함)!")
        return merged_data

    def quick_mapping_check(self):
        """빠른 매핑 상태 확인"""
        mapping_files = [
            'category_id_mapping.json',
            'dl_name_mapping.json',
            'dl_idx_to_name.json'
        ]

        print("🔍 매핑 파일 상태:")
        all_exist = True
        for filename in mapping_files:
            filepath = os.path.join(self.output_dir, filename)
            if os.path.exists(filepath):
                with open(filepath, 'r') as f:
                    data = json.load(f)
                print(f"  ✅ {filename}: {len(data)}개 항목")
            else:
                print(f"  ❌ {filename}: 없음")
                all_exist = False

        return all_exist

    def process_data(self):
        """전체 데이터 처리 파이프라인 + 클래스 불균형 해결"""
        print("COCO 어노테이션 병합 중...")
        merged_data = self.merge_coco_annotations()

        print("YOLO 형식으로 변환 중...")
        self.coco_to_yolo_format(merged_data)
        print("데이터 전처리 완료!")

        return merged_data

    def analyze_class_distribution(self, merged_data):
        """클래스별 데이터 분포 분석"""
        print("=== 클래스 분포 분석 ===")

        # 클래스별 이미지 수 계산
        class_image_count = defaultdict(int)
        class_annotation_count = defaultdict(int)

        # 이미지별 클래스 집계
        ann_by_image = {}
        for ann in merged_data['annotations']:
            img_id = ann['image_id']
            if img_id not in ann_by_image:
                ann_by_image[img_id] = set()
            ann_by_image[img_id].add(ann['category_id'])
            class_annotation_count[ann['category_id']] += 1

        # 각 클래스가 포함된 이미지 수
        for img_id, classes in ann_by_image.items():
            for class_id in classes:
                class_image_count[class_id] += 1

        # 클래스 이름 매핑
        class_names = {cat['id']: cat['name'] for cat in merged_data['categories']}

        # 분포 출력
        print(f"총 {len(merged_data['categories'])}개 클래스")
        print("\n클래스별 분포 (어노테이션 수 기준):")

        sorted_classes = sorted(class_annotation_count.items(), key=lambda x: x[1], reverse=True)

        minority_classes = []
        majority_classes = []

        for class_id, ann_count in sorted_classes:
            img_count = class_image_count[class_id]
            class_name = class_names.get(class_id, f"Unknown-{class_id}")

            print(f"  {class_name}: {ann_count}개 어노테이션, {img_count}개 이미지")

            if ann_count < 30:  # 30개 미만을 소수 클래스로 정의
                minority_classes.append((class_id, class_name, ann_count))
            elif ann_count > 100:  # 100개 초과를 다수 클래스로 정의
                majority_classes.append((class_id, class_name, ann_count))

        print(f"\n불균형 분석:")
        print(f"  소수 클래스 (<30개): {len(minority_classes)}개")
        print(f"  다수 클래스 (>100개): {len(majority_classes)}개")
        print(f"  불균형 비율: {max(class_annotation_count.values()) / min(class_annotation_count.values()):.1f}배")

        return minority_classes, majority_classes, class_annotation_count

# %% [markdown]
# # 모델 학습

# %%
class RTDETRTrainer:
    def __init__(self, data_yaml_path):
        self.data_yaml_path = data_yaml_path
        self.model = None

    def train(self, epochs=100, imgsz=640, batch=16):
        """기본 RT-DETR 모델 학습"""
        print("RT-DETR 모델 학습 시작...")
        self.model = RTDETR('rtdetr-l.pt')

        results = self.model.train(
            data=self.data_yaml_path,
            epochs=epochs,
            imgsz=imgsz,
            batch=batch,
            name='pill_rtdetr',
            save_period=10,
            patience=15,       # 조기 종료 완화
            cls=1.0,           # 클래스 손실 가중치 증가
            box=7.5,           # 박스 손실 유지
            dfl=1.5,              # Distribution focal loss (기본 1.5)

            # 학습률 조정
            lr0=0.01,          # 기본값
            lrf=0.01,
            momentum=0.937,
            weight_decay=0.0005,

            # 정규화 강화
            dropout=0.1,       # 드롭아웃 추가

            # 밝기 분포 (95-165) 고려한 증강
            hsv_v=0.2,         # 밝기 변화 제한 (기존보다 작게)
            hsv_s=0.3,         # 채도 변화 적절히
            hsv_h=0.01,        # 색조는 최소화

            # RGB 상관관계 고려
            mixup=0.0,         # 색상 혼합 최소화
            mosaic=0.3,        # 모자이크도 줄임
        )

        print("학습 완료!")
        return results

    def load_best_model(self, model_path=None):
        """최고 성능 모델 로드"""
        if model_path is None:
            model_path = 'runs/detect/pill_rtdetr/weights/best.pt'  # Phase 3 경로

        self.model = RTDETR(model_path)
        return self.model

# %%
class RTDETRInference:
    def __init__(self, model_path, mapping_file_path=None):
        self.model = RTDETR(model_path)

        # 🔥 매핑 파일 로드 (YOLO 클래스 → dl_idx)
        self.class_to_dl_idx = {}
        if mapping_file_path and os.path.exists(mapping_file_path):
            with open(mapping_file_path, 'r', encoding='utf-8') as f:
                self.class_to_dl_idx = json.load(f)
                # 문자열 키를 정수로 변환
                self.class_to_dl_idx = {int(k): int(v) for k, v in self.class_to_dl_idx.items()}
            print(f"✅ 매핑 파일 로드 완료: {len(self.class_to_dl_idx)}개 클래스")
        else:
            print("⚠️ 매핑 파일이 없습니다. 클래스 ID를 그대로 사용합니다.")

    def predict_and_generate_csv(self, test_images_path, output_csv_path, conf_thresh=0.321):
        """테스트 이미지 예측 및 제출 규칙에 맞는 CSV 파일 생성"""
        results_data = []
        annotation_id = 1  # 1부터 시작

        # 테스트 이미지 파일 목록
        test_files = glob.glob(os.path.join(test_images_path, "*.png")) + \
                    glob.glob(os.path.join(test_images_path, "*.jpg"))

        print(f"테스트 이미지 {len(test_files)}개 처리 중...")

        for img_path in test_files:
            filename = os.path.basename(img_path)

            # 🔥 image_id: 파일명에서 숫자만 추출 (100.png → 100)
            image_id = filename.split('.')[0]  # 확장자 제거
            try:
                image_id = int(image_id)  # 숫자로 변환
            except ValueError:
                # 숫자가 아닌 파일명의 경우 그대로 사용
                image_id = filename.split('.')[0]

            # 예측 수행
            results = self.model(img_path, conf=conf_thresh)

            for result in results:
                boxes = result.boxes
                if boxes is not None:
                    for box in boxes:
                        # 바운딩 박스 좌표 (xyxy 형식)
                        x1, y1, x2, y2 = box.xyxy[0].cpu().numpy()
                        confidence = box.conf[0].cpu().numpy()
                        yolo_class_id = int(box.cls[0].cpu().numpy())  # YOLO 클래스 ID

                        # 🔥 category_id: YOLO 클래스 → dl_idx 변환
                        if yolo_class_id in self.class_to_dl_idx:
                            category_id = self.class_to_dl_idx[yolo_class_id]  # 실제 dl_idx
                        else:
                            category_id = yolo_class_id  # 매핑 실패시 그대로
                            print(f"⚠️ 매핑 없음: YOLO 클래스 {yolo_class_id} → {yolo_class_id}")

                        # COCO 형식으로 변환 (xywh)
                        bbox_x = x1
                        bbox_y = y1
                        bbox_w = x2 - x1
                        bbox_h = y2 - y1

                        results_data.append({
                            'annotation_id': annotation_id,  # 1부터 시작
                            'image_id': image_id,            # 파일명에서 숫자 추출
                            'category_id': category_id,      # 실제 dl_idx
                            'bbox_x': bbox_x,
                            'bbox_y': bbox_y,
                            'bbox_w': bbox_w,
                            'bbox_h': bbox_h,
                            'score': confidence
                        })

                        annotation_id += 1

        # CSV 파일 생성
        df = pd.DataFrame(results_data)
        df.to_csv(output_csv_path, index=False)

        # 🔥 결과 분석 출력
        if len(results_data) > 0:
            unique_image_ids = df['image_id'].unique()
            unique_category_ids = df['category_id'].unique()

            print(f"\n🎯 제출 파일 생성 완료: {output_csv_path}")
            print(f"  - 총 예측: {len(results_data)}개")
            print(f"  - 이미지 수: {len(unique_image_ids)}개")
            print(f"  - 카테고리 수: {len(unique_category_ids)}개")
            print(f"  - image_id 범위: {min(unique_image_ids)} ~ {max(unique_image_ids)}")
            print(f"  - category_id (dl_idx): {sorted(unique_category_ids)}")
        else:
            print("⚠️ 예측 결과가 없습니다. 신뢰도 임계값을 낮춰보세요.")

        return df

# %% [markdown]
# # 메인 실행

# %%
def run_detailed_pipeline(data_path="./data"):
    """상세 버전 파이프라인 실행 (클래스 기반)"""
    print("=== 상세 버전 파이프라인 시작 ===")

    # 1. 데이터 전처리
    print("1. 데이터 전처리...")
    # # 전처리 실행
    # processor = RTDETRDataProcessor(data_path)
    # merged_data = processor.process_data_with_name_mapping()

    # # 매핑 결과 확인
    # processor.validate_category_mapping()

    # 2. 모델 학습
    # print("2. 모델 학습...")
    # trainer = RTDETRTrainer(f"{data_path}/yolo_format/dataset.yaml")
    # trainer.train(epochs=50, batch=8)

    # 3. 추론 및 제출 파일 생성
    print("3. 추론 및 제출 파일 생성...")
    model_path = 'runs/detect/pill_rtdetr4/weights/best.pt'
    mapping_file = f"{data_path}/yolo_format/category_id_mapping.json"  # 🔥 매핑 파일 경로

    inference = RTDETRInference(model_path, mapping_file)

    submission_df = inference.predict_and_generate_csv(
        test_images_path=f"{data_path}/test_images",
        output_csv_path="submission_detailed_0.321.csv"
    )

    print("상세 버전 파이프라인 완료!")
    return submission_df

# %%
data_path="./data"
run_detailed_pipeline(data_path)
# Out:
# === 상세 버전 파이프라인 시작 ===
# 1. 데이터 전처리...
# 3. 추론 및 제출 파일 생성...
# ✅ 매핑 파일 로드 완료: 73개 클래스
# 테스트 이미지 843개 처리 중...
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1.png: 640x640 1 보령부스파정 5mg, 1 동아가바펜틴정 800mg, 1 울트라셋이알서방정, 1 놀텍정 10mg, 64.6ms
# Speed: 3.3ms preprocess, 64.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/10.png: 640x640 1 보령부스파정 5mg, 1 가바토파정 100mg, 1 레일라정, 1 라비에트정 20mg, 64.3ms
# Speed: 3.1ms preprocess, 64.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1004.png: 640x640 1 리피토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 제미메트서방정 50/1000mg, 1 트윈스타정 40/5mg, 64.8ms
# Speed: 3.1ms preprocess, 64.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1005.png: 640x640 1 리피토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 제미메트서방정 50/1000mg, 1 트윈스타정 40/5mg, 65.3ms
# Speed: 3.2ms preprocess, 65.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/100.png: 640x640 1 보령부스파정 5mg, 1 신바로정, 1 가바토파정 100mg, 1 란스톤엘에프디티정 30mg, 64.5ms
# Speed: 3.1ms preprocess, 64.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1006.png: 640x640 1 플라빅스정 75mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누메트정 50/850mg, 1 아모잘탄정 5/100mg, 64.5ms
# Speed: 3.2ms preprocess, 64.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1003.png: 640x640 1 리피토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 제미메트서방정 50/1000mg, 1 트윈스타정 40/5mg, 64.3ms
# Speed: 3.0ms preprocess, 64.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1010.png: 640x640 1 크레스토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누비아정 50mg, 1 아모잘탄정 5/100mg, 64.9ms
# Speed: 3.1ms preprocess, 64.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1009.png: 640x640 1 크레스토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누비아정 50mg, 1 아모잘탄정 5/100mg, 66.5ms
# Speed: 3.1ms preprocess, 66.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1007.png: 640x640 1 플라빅스정 75mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누메트정 50/850mg, 1 아모잘탄정 5/100mg, 65.0ms
# Speed: 3.0ms preprocess, 65.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1012.png: 640x640 1 보령부스파정 5mg, 1 가바토파정 100mg, 1 울트라셋이알서방정, 1 놀텍정 10mg, 53.2ms
# Speed: 3.1ms preprocess, 53.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1013.png: 640x640 1 보령부스파정 5mg, 1 가바토파정 100mg, 1 울트라셋이알서방정, 1 놀텍정 10mg, 53.2ms
# Speed: 3.2ms preprocess, 53.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1014.png: 640x640 1 보령부스파정 5mg, 1 가바토파정 100mg, 1 울트라셋이알서방정, 1 놀텍정 10mg, 52.6ms
# Speed: 3.1ms preprocess, 52.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1015.png: 640x640 1 아토젯정 10/40mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타듀오정 2.5/850mg, 1 엑스포지정 5/160mg, 52.8ms
# Speed: 3.0ms preprocess, 52.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1016.png: 640x640 1 아토젯정 10/40mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타듀오정 2.5/850mg, 1 엑스포지정 5/160mg, 49.6ms
# Speed: 2.9ms preprocess, 49.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1018.png: 640x640 1 리바로정 4mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타듀오정 2.5/850mg, 1 트윈스타정 40/5mg, 50.2ms
# Speed: 3.0ms preprocess, 50.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/102.png: 640x640 1 보령부스파정 5mg, 1 신바로정, 1 가바토파정 100mg, 1 란스톤엘에프디티정 30mg, 51.7ms
# Speed: 3.3ms preprocess, 51.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1019.png: 640x640 1 리바로정 4mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타듀오정 2.5/850mg, 1 트윈스타정 40/5mg, 48.5ms
# Speed: 2.9ms preprocess, 48.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1022.png: 640x640 1 보령부스파정 5mg, 1 동아가바펜틴정 800mg, 1 레일라정, 1 에스원엠프정 20mg, 48.7ms
# Speed: 3.0ms preprocess, 48.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1020.png: 640x640 1 리바로정 4mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타듀오정 2.5/850mg, 1 트윈스타정 40/5mg, 48.5ms
# Speed: 2.9ms preprocess, 48.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1026.png: 640x640 1 크레스토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 2 트라젠타정(리나글립틴)s, 1 엑스포지정 5/160mg, 50.0ms
# Speed: 3.1ms preprocess, 50.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1023.png: 640x640 1 보령부스파정 5mg, 1 동아가바펜틴정 800mg, 1 레일라정, 1 에스원엠프정 20mg, 47.7ms
# Speed: 2.9ms preprocess, 47.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1025.png: 640x640 1 크레스토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타정(리나글립틴), 1 엑스포지정 5/160mg, 47.4ms
# Speed: 2.9ms preprocess, 47.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1029.png: 640x640 1 리피토정 20mg, 1 일양하이트린정 2mg, 1 에빅사정(메만틴염산염)(비매품), 44.6ms
# Speed: 2.9ms preprocess, 44.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1028.png: 640x640 1 리피토정 20mg, 1 일양하이트린정 2mg, 1 에빅사정(메만틴염산염)(비매품), 44.5ms
# Speed: 2.9ms preprocess, 44.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1030.png: 640x640 1 아토젯정 10/40mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 제미메트서방정 50/1000mg, 1 트윈스타정 40/5mg, 44.4ms
# Speed: 2.9ms preprocess, 44.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1027.png: 640x640 2 일양하이트린정 2mgs, 1 에빅사정(메만틴염산염)(비매품), 44.1ms
# Speed: 3.1ms preprocess, 44.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1034.png: 640x640 1 로수젯정10/5밀리그램, 1 기넥신에프정(은행엽엑스)(수출용), 1 노바스크정 5mg, 2 트라젠타정(리나글립틴)s, 44.6ms
# Speed: 3.1ms preprocess, 44.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1039.png: 640x640 1 크레스토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타정(리나글립틴), 1 아모잘탄정 5/100mg, 46.5ms
# Speed: 3.0ms preprocess, 46.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/104.png: 640x640 1 일양하이트린정 2mg, 1 아토르바정 10mg, 1 종근당글리아티린연질캡슐(콜린알포세레이트) , 44.9ms
# Speed: 3.0ms preprocess, 44.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1041.png: 640x640 1 크레스토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타정(리나글립틴), 1 아모잘탄정 5/100mg, 45.2ms
# Speed: 2.9ms preprocess, 45.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1043.png: 640x640 1 일양하이트린정 2mg, 1 아토젯정 10/40mg, 1 종근당글리아티린연질캡슐(콜린알포세레이트) , 45.5ms
# Speed: 2.9ms preprocess, 45.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1044.png: 640x640 1 일양하이트린정 2mg, 1 아토젯정 10/40mg, 1 종근당글리아티린연질캡슐(콜린알포세레이트) , 44.7ms
# Speed: 3.0ms preprocess, 44.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1045.png: 640x640 1 리바로정 4mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타정(리나글립틴), 1 엑스포지정 5/160mg, 44.1ms
# Speed: 3.0ms preprocess, 44.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1046.png: 640x640 1 리바로정 4mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타정(리나글립틴), 1 엑스포지정 5/160mg, 43.8ms
# Speed: 2.9ms preprocess, 43.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1047.png: 640x640 1 리바로정 4mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타정(리나글립틴), 1 엑스포지정 5/160mg, 42.9ms
# Speed: 2.8ms preprocess, 42.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1050.png: 640x640 1 뮤테란캡슐 100mg, 1 메가파워정 90mg/병, 1 맥시부펜이알정 300mg, 1 삼남건조수산화알루미늄겔정, 44.6ms
# Speed: 3.1ms preprocess, 44.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1051.png: 640x640 1 타이레놀정500mg, 1 뮤테란캡슐 100mg, 1 비타비백정 100mg/병, 1 삼남건조수산화알루미늄겔정, 65.6ms
# Speed: 3.3ms preprocess, 65.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1053.png: 640x640 1 타이레놀정500mg, 1 뮤테란캡슐 100mg, 1 비타비백정 100mg/병, 1 삼남건조수산화알루미늄겔정, 65.0ms
# Speed: 3.1ms preprocess, 65.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1055.png: 640x640 1 리바로정 4mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누메트엑스알서방정 100/1000mg, 1 트윈스타정 40/5mg, 64.5ms
# Speed: 3.0ms preprocess, 64.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1056.png: 640x640 1 리바로정 4mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누메트엑스알서방정 100/1000mg, 1 트윈스타정 40/5mg, 51.5ms
# Speed: 2.8ms preprocess, 51.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1057.png: 640x640 1 타이레놀정500mg, 1 뮤테란캡슐 100mg, 1 다보타민큐정 10mg/병, 1 큐시드정 31.5mg/PTP, 52.3ms
# Speed: 3.1ms preprocess, 52.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1058.png: 640x640 1 타이레놀정500mg, 1 뮤테란캡슐 100mg, 1 다보타민큐정 10mg/병, 1 큐시드정 31.5mg/PTP, 50.4ms
# Speed: 2.9ms preprocess, 50.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1060.png: 640x640 1 뮤테란캡슐 100mg, 1 메가파워정 90mg/병, 1 써스펜8시간이알서방정 650mg, 1 큐시드정 31.5mg/PTP, 50.1ms
# Speed: 3.0ms preprocess, 50.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1064.png: 640x640 1 플라빅스정 75mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 제미메트서방정 50/1000mg, 1 아모잘탄정 5/100mg, 50.2ms
# Speed: 2.9ms preprocess, 50.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1067.png: 640x640 1 크레스토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누메트엑스알서방정 100/1000mg, 1 세비카정 10/40mg, 47.9ms
# Speed: 3.0ms preprocess, 47.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1065.png: 640x640 1 플라빅스정 75mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 제미메트서방정 50/1000mg, 1 아모잘탄정 5/100mg, 50.4ms
# Speed: 3.1ms preprocess, 50.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1070.png: 640x640 1 보령부스파정 5mg, 1 가바토파정 100mg, 1 펠루비정(펠루비프로펜), 1 라비에트정 20mg, 47.1ms
# Speed: 3.1ms preprocess, 47.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1069.png: 640x640 1 보령부스파정 5mg, 1 가바토파정 100mg, 1 펠루비정(펠루비프로펜), 1 라비에트정 20mg, 48.0ms
# Speed: 3.0ms preprocess, 48.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1073.png: 640x640 1 로수젯정10/5밀리그램, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누비아정 50mg, 1 카나브정 60mg, 46.1ms
# Speed: 3.2ms preprocess, 46.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1075.png: 640x640 1 동아가바펜틴정 800mg, 1 무코스타정(레바미피드)(비매품), 1 에어탈정(아세클로페낙), 1 렉사프로정 15mg, 46.0ms
# Speed: 3.0ms preprocess, 46.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1076.png: 640x640 1 동아가바펜틴정 800mg, 1 무코스타정(레바미피드)(비매품), 1 에어탈정(아세클로페낙), 1 렉사프로정 15mg, 44.8ms
# Speed: 2.9ms preprocess, 44.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1077.png: 640x640 1 동아가바펜틴정 800mg, 1 무코스타정(레바미피드)(비매품), 1 에어탈정(아세클로페낙), 1 렉사프로정 15mg, 46.0ms
# Speed: 3.3ms preprocess, 46.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1079.png: 640x640 1 리바로정 4mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누비아정 50mg, 1 엑스포지정 5/160mg, 48.2ms
# Speed: 4.1ms preprocess, 48.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/108.png: 640x640 1 뮤테란캡슐 100mg, 1 다보타민큐정 10mg/병, 1 맥시부펜이알정 300mg, 1 큐시드정 31.5mg/PTP, 44.9ms
# Speed: 3.0ms preprocess, 44.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1080.png: 640x640 1 리바로정 4mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누비아정 50mg, 1 엑스포지정 5/160mg, 45.4ms
# Speed: 2.9ms preprocess, 45.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1085.png: 640x640 1 리피토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 엑스포지정 5/160mg, 1 자누메트정 50/850mg, 65.0ms
# Speed: 3.0ms preprocess, 65.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1081.png: 640x640 1 보령부스파정 5mg, 1 동아가바펜틴정 800mg, 1 펠루비정(펠루비프로펜), 1 케이캡정 50mg, 65.2ms
# Speed: 3.2ms preprocess, 65.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1087.png: 640x640 1 동아가바펜틴정 800mg, 1 낙소졸정 500/20mg, 1 무코스타정(레바미피드)(비매품), 1 쎄로켈정 100mg, 64.0ms
# Speed: 3.0ms preprocess, 64.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1089.png: 640x640 1 동아가바펜틴정 800mg, 1 낙소졸정 500/20mg, 1 무코스타정(레바미피드)(비매품), 1 쎄로켈정 100mg, 55.5ms
# Speed: 3.3ms preprocess, 55.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1092.png: 640x640 1 보령부스파정 5mg, 1 신바로정, 1 가바토파정 100mg, 1 케이캡정 50mg, 57.1ms
# Speed: 2.9ms preprocess, 57.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1093.png: 640x640 1 크레스토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 노바스크정 5mg, 1 제미메트서방정 50/1000mg, 50.0ms
# Speed: 3.0ms preprocess, 50.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/109.png: 640x640 1 아토젯정 10/40mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 노바스크정 5mg, 1 자누메트정 50/850mg, 51.5ms
# Speed: 3.1ms preprocess, 51.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1095.png: 640x640 1 크레스토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 노바스크정 5mg, 1 제미메트서방정 50/1000mg, 48.5ms
# Speed: 3.0ms preprocess, 48.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1097.png: 640x640 1 동아가바펜틴정 800mg, 1 무코스타정(레바미피드)(비매품), 1 졸로푸트정 100mg, 1 조인스정 200mg, 47.6ms
# Speed: 2.8ms preprocess, 47.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1096.png: 640x640 1 동아가바펜틴정 800mg, 1 무코스타정(레바미피드)(비매품), 1 졸로푸트정 100mg, 1 조인스정 200mg, 47.7ms
# Speed: 2.8ms preprocess, 47.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1098.png: 640x640 1 동아가바펜틴정 800mg, 1 무코스타정(레바미피드)(비매품), 1 졸로푸트정 100mg, 1 조인스정 200mg, 48.0ms
# Speed: 2.9ms preprocess, 48.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/110.png: 640x640 1 아토젯정 10/40mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 노바스크정 5mg, 1 자누메트정 50/850mg, 47.2ms
# Speed: 2.8ms preprocess, 47.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1100.png: 640x640 1 로수젯정10/5밀리그램, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누메트엑스알서방정 100/1000mg, 1 카나브정 60mg, 47.5ms
# Speed: 2.8ms preprocess, 47.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1101.png: 640x640 1 로수젯정10/5밀리그램, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누메트엑스알서방정 100/1000mg, 1 카나브정 60mg, 46.7ms
# Speed: 2.8ms preprocess, 46.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1105.png: 640x640 1 아토젯정 10/40mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누비아정 50mg, 1 트윈스타정 40/5mg, 45.8ms
# Speed: 2.8ms preprocess, 45.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1109.png: 640x640 1 크레스토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타정(리나글립틴), 1 세비카정 10/40mg, 44.8ms
# Speed: 2.8ms preprocess, 44.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1111.png: 640x640 1 리바로정 4mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타정(리나글립틴), 1 세비카정 10/40mg, 44.4ms
# Speed: 2.9ms preprocess, 44.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1114.png: 640x640 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타듀오정 2.5/850mg, 1 세비카정 10/40mg, 44.3ms
# Speed: 2.8ms preprocess, 44.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1115.png: 640x640 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타듀오정 2.5/850mg, 1 세비카정 10/40mg, 44.7ms
# Speed: 2.8ms preprocess, 44.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1116.png: 640x640 1 아토젯정 10/40mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타듀오정 2.5/850mg, 1 세비카정 10/40mg, 44.4ms
# Speed: 2.8ms preprocess, 44.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1118.png: 640x640 1 가바토파정 100mg, 1 무코스타정(레바미피드)(비매품), 1 렉사프로정 15mg, 1 조인스정 200mg, 43.7ms
# Speed: 2.9ms preprocess, 43.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1119.png: 640x640 1 가바토파정 100mg, 1 무코스타정(레바미피드)(비매품), 1 렉사프로정 15mg, 1 조인스정 200mg, 44.5ms
# Speed: 2.9ms preprocess, 44.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/112.png: 640x640 1 동아가바펜틴정 800mg, 1 신바로정, 1 무코스타정(레바미피드)(비매품), 1 쎄로켈정 100mg, 45.0ms
# Speed: 3.1ms preprocess, 45.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1121.png: 640x640 1 리바로정 4mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타정(리나글립틴), 1 아모잘탄정 5/100mg, 44.2ms
# Speed: 2.8ms preprocess, 44.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1123.png: 640x640 1 크레스토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누메트정 50/850mg, 1 트윈스타정 40/5mg, 44.0ms
# Speed: 2.8ms preprocess, 44.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1125.png: 640x640 1 크레스토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누메트정 50/850mg, 1 트윈스타정 40/5mg, 42.9ms
# Speed: 2.8ms preprocess, 42.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1126.png: 640x640 1 크레스토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누메트엑스알서방정 100/1000mg, 1 엑스포지정 5/160mg, 43.0ms
# Speed: 2.8ms preprocess, 43.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/113.png: 640x640 1 동아가바펜틴정 800mg, 1 신바로정, 1 무코스타정(레바미피드)(비매품), 1 쎄로켈정 100mg, 45.0ms
# Speed: 2.8ms preprocess, 45.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1129.png: 640x640 1 플라빅스정 75mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누비아정 50mg, 1 트윈스타정 40/5mg, 43.6ms
# Speed: 2.9ms preprocess, 43.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1136.png: 640x640 1 보령부스파정 5mg, 1 동아가바펜틴정 800mg, 1 신바로정, 1 란스톤엘에프디티정 30mg, 43.5ms
# Speed: 3.0ms preprocess, 43.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1135.png: 640x640 1 보령부스파정 5mg, 1 동아가바펜틴정 800mg, 1 신바로정, 1 란스톤엘에프디티정 30mg, 43.6ms
# Speed: 2.9ms preprocess, 43.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1138.png: 640x640 1 플라빅스정 75mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 제미메트서방정 50/1000mg, 1 세비카정 10/40mg, 43.7ms
# Speed: 2.8ms preprocess, 43.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/114.png: 640x640 1 동아가바펜틴정 800mg, 1 신바로정, 1 무코스타정(레바미피드)(비매품), 1 쎄로켈정 100mg, 42.9ms
# Speed: 2.9ms preprocess, 42.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1140.png: 640x640 1 플라빅스정 75mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 제미메트서방정 50/1000mg, 1 세비카정 10/40mg, 43.7ms
# Speed: 2.9ms preprocess, 43.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1141.png: 640x640 1 뮤테란캡슐 100mg, 1 비타비백정 100mg/병, 1 리렉스펜정 300mg/PTP, 1 큐시드정 31.5mg/PTP, 43.3ms
# Speed: 3.0ms preprocess, 43.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1142.png: 640x640 1 비타비백정 100mg/병, 1 리렉스펜정 300mg/PTP, 1 큐시드정 31.5mg/PTP, 42.9ms
# Speed: 2.9ms preprocess, 42.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1143.png: 640x640 1 비타비백정 100mg/병, 1 리렉스펜정 300mg/PTP, 1 큐시드정 31.5mg/PTP, 43.7ms
# Speed: 2.8ms preprocess, 43.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1144.png: 640x640 1 크레스토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누메트엑스알서방정 100/1000mg, 1 아모잘탄정 5/100mg, 43.0ms
# Speed: 2.8ms preprocess, 43.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1148.png: 640x640 1 리피토정 20mg, 1 일양하이트린정 2mg, 1 카발린캡슐 25mg, 44.2ms
# Speed: 2.8ms preprocess, 44.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1149.png: 640x640 1 리피토정 20mg, 1 일양하이트린정 2mg, 1 카발린캡슐 25mg, 45.8ms
# Speed: 2.8ms preprocess, 45.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1150.png: 640x640 1 리바로정 4mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 제미메트서방정 50/1000mg, 1 카나브정 60mg, 43.5ms
# Speed: 2.9ms preprocess, 43.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/115.png: 640x640 1 로수젯정10/5밀리그램, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누메트정 50/850mg, 1 트윈스타정 40/5mg, 64.6ms
# Speed: 3.1ms preprocess, 64.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1153.png: 640x640 1 리피토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 노바스크정 5mg, 1 자누비아정 50mg, 64.2ms
# Speed: 2.9ms preprocess, 64.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1154.png: 640x640 1 리피토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 노바스크정 5mg, 1 자누비아정 50mg, 52.1ms
# Speed: 2.8ms preprocess, 52.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1155.png: 640x640 1 리피토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 노바스크정 5mg, 1 자누비아정 50mg, 52.0ms
# Speed: 2.9ms preprocess, 52.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1156.png: 640x640 1 일양하이트린정 2mg, 1 크레스토정 20mg, 1 에빅사정(메만틴염산염)(비매품), 50.0ms
# Speed: 3.0ms preprocess, 50.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1157.png: 640x640 1 일양하이트린정 2mg, 1 크레스토정 20mg, 1 에빅사정(메만틴염산염)(비매품), 48.5ms
# Speed: 2.9ms preprocess, 48.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1158.png: 640x640 1 일양하이트린정 2mg, 1 크레스토정 20mg, 1 에빅사정(메만틴염산염)(비매품), 48.5ms
# Speed: 2.8ms preprocess, 48.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1159.png: 640x640 1 리피토정 20mg, 1 일양하이트린정 2mg, 1 종근당글리아티린연질캡슐(콜린알포세레이트) , 48.5ms
# Speed: 2.8ms preprocess, 48.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1161.png: 640x640 1 리피토정 20mg, 1 일양하이트린정 2mg, 1 종근당글리아티린연질캡슐(콜린알포세레이트) , 64.1ms
# Speed: 3.2ms preprocess, 64.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1163.png: 640x640 1 동아가바펜틴정 800mg, 1 레일라정, 1 무코스타정(레바미피드)(비매품), 1 쎄로켈정 100mg, 65.0ms
# Speed: 3.0ms preprocess, 65.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1164.png: 640x640 1 동아가바펜틴정 800mg, 1 레일라정, 1 무코스타정(레바미피드)(비매품), 1 쎄로켈정 100mg, 52.5ms
# Speed: 3.1ms preprocess, 52.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1166.png: 640x640 1 로수젯정10/5밀리그램, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누메트정 50/850mg, 1 아모잘탄정 5/100mg, 53.0ms
# Speed: 2.9ms preprocess, 53.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1167.png: 640x640 1 로수젯정10/5밀리그램, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누메트정 50/850mg, 1 아모잘탄정 5/100mg, 65.3ms
# Speed: 3.4ms preprocess, 65.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1168.png: 640x640 1 리바로정 4mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타듀오정 2.5/850mg, 1 아모잘탄정 5/100mg, 65.2ms
# Speed: 3.0ms preprocess, 65.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1170.png: 640x640 1 리바로정 4mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타듀오정 2.5/850mg, 1 아모잘탄정 5/100mg, 64.3ms
# Speed: 2.9ms preprocess, 64.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1171.png: 640x640 1 가바토파정 100mg, 1 무코스타정(레바미피드)(비매품), 1 에어탈정(아세클로페낙), 1 쎄로켈정 100mg, 64.1ms
# Speed: 2.9ms preprocess, 64.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1173.png: 640x640 1 가바토파정 100mg, 1 무코스타정(레바미피드)(비매품), 1 에어탈정(아세클로페낙), 1 쎄로켈정 100mg, 52.0ms
# Speed: 3.0ms preprocess, 52.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1174.png: 640x640 1 리바로정 4mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타듀오정 2.5/850mg, 1 세비카정 10/40mg, 51.7ms
# Speed: 3.0ms preprocess, 51.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1176.png: 640x640 1 리바로정 4mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타듀오정 2.5/850mg, 1 세비카정 10/40mg, 51.7ms
# Speed: 2.8ms preprocess, 51.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1178.png: 640x640 1 플라빅스정 75mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누메트엑스알서방정 100/1000mg, 1 카나브정 60mg, 64.0ms
# Speed: 3.0ms preprocess, 64.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/118.png: 640x640 1 일양하이트린정 2mg, 1 오마코연질캡슐(오메가-3-산에틸에스테르90), 1 에빅사정(메만틴염산염)(비매품), 63.8ms
# Speed: 2.8ms preprocess, 63.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1180.png: 640x640 1 일양하이트린정 2mg, 1 아토르바정 10mg, 1 콜리네이트연질캡슐 400mg, 67.9ms
# Speed: 2.9ms preprocess, 67.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1184.png: 640x640 1 보령부스파정 5mg, 1 가바토파정 100mg, 1 펠루비정(펠루비프로펜), 1 놀텍정 10mg, 55.5ms
# Speed: 2.8ms preprocess, 55.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1185.png: 640x640 1 보령부스파정 5mg, 1 가바토파정 100mg, 2 펠루비정(펠루비프로펜)s, 1 놀텍정 10mg, 54.0ms
# Speed: 3.2ms preprocess, 54.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1187.png: 640x640 1 타이레놀정500mg, 1 뮤테란캡슐 100mg, 1 트루비타정 60mg/병, 1 삼남건조수산화알루미늄겔정, 51.2ms
# Speed: 3.0ms preprocess, 51.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1186.png: 640x640 1 타이레놀정500mg, 1 뮤테란캡슐 100mg, 1 트루비타정 60mg/병, 1 삼남건조수산화알루미늄겔정, 48.0ms
# Speed: 2.8ms preprocess, 48.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1189.png: 640x640 1 뮤테란캡슐 100mg, 1 알드린정, 1 메가파워정 90mg/병, 1 리렉스펜정 300mg/PTP, 64.2ms
# Speed: 3.0ms preprocess, 64.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/119.png: 640x640 1 일양하이트린정 2mg, 1 오마코연질캡슐(오메가-3-산에틸에스테르90), 1 에빅사정(메만틴염산염)(비매품), 65.0ms
# Speed: 2.9ms preprocess, 65.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1190.png: 640x640 1 뮤테란캡슐 100mg, 1 알드린정, 1 메가파워정 90mg/병, 1 리렉스펜정 300mg/PTP, 52.6ms
# Speed: 2.8ms preprocess, 52.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1191.png: 640x640 1 뮤테란캡슐 100mg, 1 알드린정, 1 메가파워정 90mg/병, 1 리렉스펜정 300mg/PTP, 52.8ms
# Speed: 2.9ms preprocess, 52.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1192.png: 640x640 1 보령부스파정 5mg, 1 동아가바펜틴정 800mg, 1 신바로정, 1 놀텍정 10mg, 49.5ms
# Speed: 2.9ms preprocess, 49.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1194.png: 640x640 1 보령부스파정 5mg, 1 동아가바펜틴정 800mg, 1 신바로정, 1 놀텍정 10mg, 49.4ms
# Speed: 2.9ms preprocess, 49.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1196.png: 640x640 1 아토젯정 10/40mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타정(리나글립틴), 1 카나브정 60mg, 49.2ms
# Speed: 2.8ms preprocess, 49.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1198.png: 640x640 1 플라빅스정 75mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타정(리나글립틴), 1 카나브정 60mg, 48.8ms
# Speed: 2.8ms preprocess, 48.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1197.png: 640x640 1 아토젯정 10/40mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타정(리나글립틴), 1 카나브정 60mg, 47.8ms
# Speed: 2.8ms preprocess, 47.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1199.png: 640x640 1 플라빅스정 75mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타정(리나글립틴), 1 카나브정 60mg, 47.2ms
# Speed: 2.8ms preprocess, 47.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/120.png: 640x640 1 일양하이트린정 2mg, 1 오마코연질캡슐(오메가-3-산에틸에스테르90), 1 에빅사정(메만틴염산염)(비매품), 46.9ms
# Speed: 2.8ms preprocess, 46.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1204.png: 640x640 1 일양하이트린정 2mg, 1 리피로우정 20mg, 44.4ms
# Speed: 3.0ms preprocess, 44.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1201.png: 640x640 1 보령부스파정 5mg, 1 가바토파정 100mg, 1 펠루비정(펠루비프로펜), 1 무코스타정(레바미피드)(비매품), 44.6ms
# Speed: 3.1ms preprocess, 44.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1206.png: 640x640 1 일양하이트린정 2mg, 1 리피로우정 20mg, 44.3ms
# Speed: 2.9ms preprocess, 44.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1207.png: 640x640 1 리피토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누비아정 50mg, 1 카나브정 60mg, 44.8ms
# Speed: 2.9ms preprocess, 44.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1209.png: 640x640 1 리피토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누비아정 50mg, 1 카나브정 60mg, 43.7ms
# Speed: 3.0ms preprocess, 43.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1210.png: 640x640 1 아토젯정 10/40mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 제미메트서방정 50/1000mg, 1 엑스포지정 5/160mg, 66.2ms
# Speed: 3.1ms preprocess, 66.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1213.png: 640x640 1 뮤테란캡슐 100mg, 1 메가파워정 90mg/병, 1 타이레놀이알서방정(아세트아미노펜)(수출용), 1 큐시드정 31.5mg/PTP, 66.8ms
# Speed: 3.2ms preprocess, 66.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1212.png: 640x640 1 아토젯정 10/40mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 제미메트서방정 50/1000mg, 1 엑스포지정 5/160mg, 64.3ms
# Speed: 3.1ms preprocess, 64.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1214.png: 640x640 1 뮤테란캡슐 100mg, 1 메가파워정 90mg/병, 1 타이레놀이알서방정(아세트아미노펜)(수출용), 1 큐시드정 31.5mg/PTP, 52.7ms
# Speed: 3.1ms preprocess, 52.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1216.png: 640x640 1 동아가바펜틴정 800mg, 1 울트라셋이알서방정, 1 무코스타정(레바미피드)(비매품), 1 쎄로켈정 100mg, 52.8ms
# Speed: 2.9ms preprocess, 52.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/122.png: 640x640 1 리바로정 4mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누메트정 50/850mg, 1 아모잘탄정 5/100mg, 50.4ms
# Speed: 2.9ms preprocess, 50.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1219.png: 640x640 1 동아가바펜틴정 800mg, 1 비모보정 500/20mg, 1 무코스타정(레바미피드)(비매품), 1 쎄로켈정 100mg, 54.4ms
# Speed: 3.2ms preprocess, 54.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1220.png: 640x640 1 동아가바펜틴정 800mg, 1 비모보정 500/20mg, 1 무코스타정(레바미피드)(비매품), 1 쎄로켈정 100mg, 50.8ms
# Speed: 2.9ms preprocess, 50.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1222.png: 640x640 1 로수젯정10/5밀리그램, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누메트정 50/850mg, 1 세비카정 10/40mg, 49.7ms
# Speed: 3.3ms preprocess, 49.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1224.png: 640x640 1 로수젯정10/5밀리그램, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누메트정 50/850mg, 1 세비카정 10/40mg, 49.5ms
# Speed: 2.9ms preprocess, 49.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1226.png: 640x640 1 아토젯정 10/40mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 노바스크정 5mg, 1 자누메트엑스알서방정 100/1000mg, 50.0ms
# Speed: 3.0ms preprocess, 50.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1227.png: 640x640 1 아토젯정 10/40mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 노바스크정 5mg, 1 자누메트엑스알서방정 100/1000mg, 49.5ms
# Speed: 3.0ms preprocess, 49.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1232.png: 640x640 1 리바로정 4mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누메트엑스알서방정 100/1000mg, 1 엑스포지정 5/160mg, 48.9ms
# Speed: 3.1ms preprocess, 48.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1235.png: 640x640 1 보령부스파정 5mg, 1 신바로정, 1 가바토파정 100mg, 1 라비에트정 20mg, 48.7ms
# Speed: 2.9ms preprocess, 48.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1237.png: 640x640 1 보령부스파정 5mg, 1 낙소졸정 500/20mg, 1 가바토파정 100mg, 1 케이캡정 50mg, 50.2ms
# Speed: 3.0ms preprocess, 50.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1238.png: 640x640 1 보령부스파정 5mg, 1 낙소졸정 500/20mg, 1 가바토파정 100mg, 1 케이캡정 50mg, 53.1ms
# Speed: 3.3ms preprocess, 53.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/124.png: 640x640 1 보령부스파정 5mg, 1 동아가바펜틴정 800mg, 1 펠루비정(펠루비프로펜), 1 라비에트정 20mg, 47.1ms
# Speed: 3.3ms preprocess, 47.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1239.png: 640x640 1 보령부스파정 5mg, 1 낙소졸정 500/20mg, 1 가바토파정 100mg, 1 케이캡정 50mg, 46.3ms
# Speed: 3.0ms preprocess, 46.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1242.png: 640x640 1 보령부스파정 5mg, 1 동아가바펜틴정 800mg, 1 비모보정 500/20mg, 1 케이캡정 50mg, 45.4ms
# Speed: 3.1ms preprocess, 45.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1243.png: 640x640 1 아토젯정 10/40mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타듀오정 2.5/850mg, 1 트윈스타정 40/5mg, 47.5ms
# Speed: 3.0ms preprocess, 47.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1245.png: 640x640 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타듀오정 2.5/850mg, 1 트윈스타정 40/5mg, 45.6ms
# Speed: 3.1ms preprocess, 45.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1246.png: 640x640 1 크레스토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 제미메트서방정 50/1000mg, 1 카나브정 60mg, 46.1ms
# Speed: 3.2ms preprocess, 46.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/125.png: 640x640 1 보령부스파정 5mg, 1 동아가바펜틴정 800mg, 1 펠루비정(펠루비프로펜), 1 라비에트정 20mg, 45.1ms
# Speed: 3.2ms preprocess, 45.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1248.png: 640x640 1 크레스토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 제미메트서방정 50/1000mg, 1 카나브정 60mg, 47.0ms
# Speed: 3.2ms preprocess, 47.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1244.png: 640x640 1 아토젯정 10/40mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타듀오정 2.5/850mg, 1 트윈스타정 40/5mg, 45.1ms
# Speed: 3.0ms preprocess, 45.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1250.png: 640x640 1 타이레놀정500mg, 1 뮤테란캡슐 100mg, 1 다보타민큐정 10mg/병, 1 삼남건조수산화알루미늄겔정, 46.3ms
# Speed: 2.9ms preprocess, 46.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1251.png: 640x640 1 타이레놀정500mg, 1 뮤테란캡슐 100mg, 1 다보타민큐정 10mg/병, 1 삼남건조수산화알루미늄겔정, 45.8ms
# Speed: 3.0ms preprocess, 45.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1252.png: 640x640 1 리바로정 4mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타듀오정 2.5/850mg, 1 엑스포지정 5/160mg, 45.1ms
# Speed: 3.0ms preprocess, 45.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1254.png: 640x640 1 리바로정 4mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타듀오정 2.5/850mg, 1 엑스포지정 5/160mg, 45.0ms
# Speed: 3.1ms preprocess, 45.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/126.png: 640x640 1 보령부스파정 5mg, 1 동아가바펜틴정 800mg, 1 펠루비정(펠루비프로펜), 1 라비에트정 20mg, 45.0ms
# Speed: 3.1ms preprocess, 45.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1256.png: 640x640 1 보령부스파정 5mg, 1 동아가바펜틴정 800mg, 1 낙소졸정 500/20mg, 1 스토가정 10mg, 45.4ms
# Speed: 3.0ms preprocess, 45.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1261.png: 640x640 1 리피토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누비아정 50mg, 1 세비카정 10/40mg, 43.7ms
# Speed: 2.9ms preprocess, 43.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1263.png: 640x640 1 리피토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누비아정 50mg, 1 세비카정 10/40mg, 44.9ms
# Speed: 2.9ms preprocess, 44.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1262.png: 640x640 1 리피토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 세비카정 10/40mg, 44.4ms
# Speed: 3.1ms preprocess, 44.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1264.png: 640x640 2 일양하이트린정 2mgs, 1 로수젯정10/5밀리그램, 45.9ms
# Speed: 3.4ms preprocess, 45.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/1265.png: 640x640 1 일양하이트린정 2mg, 1 로수젯정10/5밀리그램, 1 아질렉트정(라사길린메실산염), 44.6ms
# Speed: 3.0ms preprocess, 44.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# ...
# Speed: 2.8ms preprocess, 45.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/929.png: 640x640 1 리피토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누메트엑스알서방정 100/1000mg, 1 아모잘탄정 5/100mg, 47.5ms
# Speed: 2.9ms preprocess, 47.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/930.png: 640x640 1 리피토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 자누메트엑스알서방정 100/1000mg, 1 아모잘탄정 5/100mg, 46.5ms
# Speed: 3.1ms preprocess, 46.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/931.png: 640x640 1 보령부스파정 5mg, 1 동아가바펜틴정 800mg, 1 비모보정 500/20mg, 1 스토가정 10mg, 45.7ms
# Speed: 2.9ms preprocess, 45.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/936.png: 640x640 1 타이레놀정500mg, 1 뮤테란캡슐 100mg, 1 트루비타정 60mg/병, 1 큐시드정 31.5mg/PTP, 46.7ms
# Speed: 2.9ms preprocess, 46.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/932.png: 640x640 1 보령부스파정 5mg, 1 비모보정 500/20mg, 1 스토가정 10mg, 45.4ms
# Speed: 3.0ms preprocess, 45.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/933.png: 640x640 1 보령부스파정 5mg, 1 동아가바펜틴정 800mg, 1 비모보정 500/20mg, 1 스토가정 10mg, 46.0ms
# Speed: 2.8ms preprocess, 46.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/937.png: 640x640 1 타이레놀정500mg, 1 뮤테란캡슐 100mg, 1 알드린정, 1 삐콤씨에프정 618.6mg/병, 43.6ms
# Speed: 3.0ms preprocess, 43.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/938.png: 640x640 1 타이레놀정500mg, 1 뮤테란캡슐 100mg, 1 알드린정, 1 삐콤씨에프정 618.6mg/병, 44.2ms
# Speed: 3.1ms preprocess, 44.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/940.png: 640x640 1 리피토정 20mg, 1 일양하이트린정 2mg, 1 리리카캡슐 150mg, 44.4ms
# Speed: 2.9ms preprocess, 44.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/941.png: 640x640 1 리피토정 20mg, 1 일양하이트린정 2mg, 1 리리카캡슐 150mg, 45.2ms
# Speed: 3.1ms preprocess, 45.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/942.png: 640x640 1 리피토정 20mg, 1 일양하이트린정 2mg, 1 리리카캡슐 150mg, 43.4ms
# Speed: 2.9ms preprocess, 43.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/945.png: 640x640 1 플라빅스정 75mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 노바스크정 5mg, 1 자누메트정 50/850mg, 43.8ms
# Speed: 2.9ms preprocess, 43.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/947.png: 640x640 1 리피토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타정(리나글립틴), 1 세비카정 10/40mg, 44.6ms
# Speed: 2.9ms preprocess, 44.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/948.png: 640x640 1 리피토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 2 트라젠타정(리나글립틴)s, 1 세비카정 10/40mg, 44.2ms
# Speed: 2.9ms preprocess, 44.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/95.png: 640x640 1 일양하이트린정 2mg, 1 리바로정 4mg, 44.4ms
# Speed: 2.9ms preprocess, 44.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/949.png: 640x640 1 크레스토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타듀오정 2.5/850mg, 1 엑스포지정 5/160mg, 43.7ms
# Speed: 2.9ms preprocess, 43.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/950.png: 640x640 1 크레스토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타듀오정 2.5/850mg, 1 엑스포지정 5/160mg, 44.2ms
# Speed: 3.0ms preprocess, 44.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/952.png: 640x640 1 크레스토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타듀오정 2.5/850mg, 1 아모잘탄정 5/100mg, 44.2ms
# Speed: 2.9ms preprocess, 44.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/951.png: 640x640 1 크레스토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타듀오정 2.5/850mg, 1 엑스포지정 5/160mg, 44.2ms
# Speed: 2.9ms preprocess, 44.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/954.png: 640x640 1 크레스토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타듀오정 2.5/850mg, 1 아모잘탄정 5/100mg, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/953.png: 640x640 1 크레스토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타듀오정 2.5/850mg, 1 아모잘탄정 5/100mg, 44.1ms
# Speed: 2.9ms preprocess, 44.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/956.png: 640x640 1 보령부스파정 5mg, 1 동아가바펜틴정 800mg, 1 울트라셋이알서방정, 1 스토가정 10mg, 44.2ms
# Speed: 2.9ms preprocess, 44.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/957.png: 640x640 1 보령부스파정 5mg, 1 동아가바펜틴정 800mg, 1 울트라셋이알서방정, 1 스토가정 10mg, 44.2ms
# Speed: 2.9ms preprocess, 44.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/962.png: 640x640 1 보령부스파정 5mg, 1 동아가바펜틴정 800mg, 1 레일라정, 1 스토가정 10mg, 44.6ms
# Speed: 2.8ms preprocess, 44.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/966.png: 640x640 1 보령부스파정 5mg, 1 낙소졸정 500/20mg, 1 가바토파정 100mg, 1 란스톤엘에프디티정 30mg, 44.3ms
# Speed: 2.9ms preprocess, 44.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/968.png: 640x640 1 일양하이트린정 2mg, 1 리바로정 4mg, 1 카발린캡슐 25mg, 44.2ms
# Speed: 2.9ms preprocess, 44.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/967.png: 640x640 1 일양하이트린정 2mg, 1 리바로정 4mg, 1 카발린캡슐 25mg, 43.9ms
# Speed: 2.8ms preprocess, 43.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/97.png: 640x640 1 보령부스파정 5mg, 1 가바토파정 100mg, 1 비모보정 500/20mg, 1 스토가정 10mg, 47.8ms
# Speed: 3.2ms preprocess, 47.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/972.png: 640x640 1 보령부스파정 5mg, 1 동아가바펜틴정 800mg, 1 울트라셋이알서방정, 1 라비에트정 20mg, 44.0ms
# Speed: 2.9ms preprocess, 44.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/973.png: 640x640 1 보령부스파정 5mg, 1 동아가바펜틴정 800mg, 1 비모보정 500/20mg, 1 라비에트정 20mg, 43.7ms
# Speed: 2.8ms preprocess, 43.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/974.png: 640x640 1 보령부스파정 5mg, 1 동아가바펜틴정 800mg, 1 비모보정 500/20mg, 1 라비에트정 20mg, 44.0ms
# Speed: 2.8ms preprocess, 44.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/975.png: 640x640 1 보령부스파정 5mg, 1 비모보정 500/20mg, 1 라비에트정 20mg, 44.0ms
# Speed: 2.9ms preprocess, 44.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/979.png: 640x640 1 일양하이트린정 2mg, 1 리피로우정 20mg, 1 종근당글리아티린연질캡슐(콜린알포세레이트) , 43.3ms
# Speed: 3.0ms preprocess, 43.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/980.png: 640x640 2 일양하이트린정 2mgs, 1 종근당글리아티린연질캡슐(콜린알포세레이트) , 43.2ms
# Speed: 3.2ms preprocess, 43.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/982.png: 640x640 1 뮤테란캡슐 100mg, 1 알드린정, 1 비타비백정 100mg/병, 1 써스펜8시간이알서방정 650mg, 43.0ms
# Speed: 3.0ms preprocess, 43.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/983.png: 640x640 1 뮤테란캡슐 100mg, 1 알드린정, 1 비타비백정 100mg/병, 1 써스펜8시간이알서방정 650mg, 43.6ms
# Speed: 2.9ms preprocess, 43.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/984.png: 640x640 1 뮤테란캡슐 100mg, 1 알드린정, 1 비타비백정 100mg/병, 1 써스펜8시간이알서방정 650mg, 43.1ms
# Speed: 2.9ms preprocess, 43.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/986.png: 640x640 1 보령부스파정 5mg, 1 가바토파정 100mg, 1 레일라정, 1 놀텍정 10mg, 43.3ms
# Speed: 3.1ms preprocess, 43.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/985.png: 640x640 1 보령부스파정 5mg, 1 가바토파정 100mg, 1 레일라정, 1 놀텍정 10mg, 42.9ms
# Speed: 2.9ms preprocess, 42.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/988.png: 640x640 1 로수젯정10/5밀리그램, 1 기넥신에프정(은행엽엑스)(수출용), 1 노바스크정 5mg, 1 자누비아정 50mg, 42.9ms
# Speed: 3.0ms preprocess, 42.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/989.png: 640x640 1 로수젯정10/5밀리그램, 1 기넥신에프정(은행엽엑스)(수출용), 1 노바스크정 5mg, 1 자누비아정 50mg, 43.2ms
# Speed: 2.9ms preprocess, 43.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/990.png: 640x640 1 로수젯정10/5밀리그램, 1 기넥신에프정(은행엽엑스)(수출용), 1 노바스크정 5mg, 1 자누비아정 50mg, 43.5ms
# Speed: 2.9ms preprocess, 43.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/993.png: 640x640 1 가바토파정 100mg, 1 펠루비정(펠루비프로펜), 1 무코스타정(레바미피드)(비매품), 1 쎄로켈정 100mg, 42.9ms
# Speed: 2.9ms preprocess, 42.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/991.png: 640x640 1 가바토파정 100mg, 1 펠루비정(펠루비프로펜), 1 무코스타정(레바미피드)(비매품), 1 쎄로켈정 100mg, 41.9ms
# Speed: 3.0ms preprocess, 41.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/996.png: 640x640 1 크레스토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타듀오정 2.5/850mg, 1 세비카정 10/40mg, 41.9ms
# Speed: 2.9ms preprocess, 41.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/994.png: 640x640 1 크레스토정 20mg, 1 기넥신에프정(은행엽엑스)(수출용), 1 트라젠타듀오정 2.5/850mg, 1 세비카정 10/40mg, 42.1ms
# Speed: 2.9ms preprocess, 42.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/997.png: 640x640 1 보령부스파정 5mg, 1 동아가바펜틴정 800mg, 1 레일라정, 1 라비에트정 20mg, 41.9ms
# Speed: 3.1ms preprocess, 41.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/998.png: 640x640 1 보령부스파정 5mg, 1 동아가바펜틴정 800mg, 1 레일라정, 1 라비에트정 20mg, 41.8ms
# Speed: 2.8ms preprocess, 41.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Codeit_AI_4th_Drug_image_CV_project/data/test_images/999.png: 640x640 1 보령부스파정 5mg, 1 동아가바펜틴정 800mg, 1 레일라정, 1 라비에트정 20mg, 41.8ms
# Speed: 3.0ms preprocess, 41.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 🎯 제출 파일 생성 완료: submission_detailed_0.321.csv
#   - 총 예측: 3207개
#   - 이미지 수: 843개
#   - 카테고리 수: 73개
#   - image_id 범위: 1 ~ 1500
#   - category_id (dl_idx): [np.int64(1899), np.int64(2482), np.int64(3350), np.int64(3482), np.int64(3543), np.int64(3742), np.int64(3831), np.int64(4377), np.int64(4542), np.int64(5093), np.int64(5885), np.int64(6191), np.int64(6562), np.int64(10220), np.int64(12080), np.int64(12246), np.int64(12419), np.int64(12777), np.int64(13394), np.int64(13899), np.int64(16231), np.int64(16261), np.int64(16547), np.int64(16550), np.int64(16687), np.int64(18109), np.int64(18146), np.int64(18356), np.int64(19231), np.int64(19551), np.int64(19606), np.int64(19860), np.int64(20013), np.int64(20237), np.int64(20876), np.int64(21025), np.int64(21324), np.int64(21770), np.int64(22073), np.int64(22346), np.int64(22361), np.int64(22626), np.int64(23202), np.int64(23222), np.int64(24849), np.int64(25366), np.int64(25437), np.int64(25468), np.int64(27652), np.int64(27732), np.int64(27776), np.int64(27925), np.int64(27992), np.int64(28762), np.int64(29344), np.int64(29450), np.int64(29666), np.int64(29870), np.int64(30307), np.int64(31704), np.int64(31862), np.int64(31884), np.int64(32309), np.int64(33008), np.int64(33207), np.int64(33877), np.int64(33879), np.int64(34596), np.int64(35205), np.int64(36636), np.int64(38161), np.int64(41767), np.int64(44198)]
# 상세 버전 파이프라인 완료!
#       annotation_id  image_id  category_id      bbox_x      bbox_y  \
# 0                 1         1         1899  156.987640  252.882614
# 1                 2         1        24849  172.572769  742.589417
# 2                 3         1        27925  597.062561  676.567261
# 3                 4         1        16550  556.077454   69.204926
# 4                 5        10        29450   99.749962  237.154114
# ...             ...       ...          ...         ...         ...
# 3202           3203       998        21770  157.786057  840.017761
# 3203           3204       999        29450  101.729050  236.996536
# 3204           3205       999        16550   76.675674  683.673584
# 3205           3206       999         1899  643.566528  844.980835
# 3206           3207       999        21770  642.512817  290.026794
#
#           bbox_w      bbox_h       score
# 0     205.143280  124.492630  0.60866004
# 1     184.502396  289.272278  0.56101143
# 2     258.053223  472.228882   0.5204878
# 3     399.877930  408.751770   0.5134273
# 4     410.635132  214.854218  0.73182136
# ...          ...         ...         ...
# 3202  191.427383  186.386414  0.48122332
# 3203  409.250061  216.013168    0.740783
# 3204  294.948364  500.846558   0.5978864
# 3205  187.193298  188.942139  0.53024524
# 3206  189.758423  182.185425  0.50298303
#
# [3207 rows x 8 columns]
